# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sy
from scipy import stats
import pylab
import re

# %%
with open ('Background_0195_0257_Speed__03.txt','r') as f:
    times=[];
    PDvalue = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times.append(float(data[0]))
            PDvalue.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times,PDvalue,'r')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
with open ('Run5_0195_0257_Speed__03.txt','r') as f:
    times5=[];
    PDvalue5 = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times5.append(float(data[0]))
            PDvalue5.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times, PDvalue, 'r',times5,PDvalue5,'b')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
with open ('Run6_0195_0257_Speed__03.txt','r') as f:
    times6=[];
    PDvalue6 = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times6.append(float(data[0]))
            PDvalue6.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times5, PDvalue5, 'r',times6,PDvalue6,'b')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
with open ('Run7_0195_0257_Speed__03.txt','r') as f:
    times7=[];
    PDvalue7 = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times7.append(float(data[0]))
            PDvalue7.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times5, PDvalue5, 'r',times7,PDvalue7,'b')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
with open ('Run8_0195_0257_Speed__03.txt','r') as f:
    times8=[];
    PDvalue8 = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times8.append(float(data[0]))
            PDvalue8.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times5, PDvalue5, 'r',times8,PDvalue8,'b')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
with open ('Run9_0195_0257_Speed__03.txt','r') as f:
    times9=[];
    PDvalue9 = [];
    for line in f:
        line = line.strip()
        if line:
            data = line.split()
            times9.append(float(data[0]))
            PDvalue9.append(float(data[1]))
        
    
    #lines.append(line)
    
            #print(len(data))
    #print(times)
    #print(PDvalue)
    
    plt.plot(times5, PDvalue5, 'r',times9,PDvalue9,'b')
    plt.xlabel('Stage Position (arb)')
    plt.ylabel('PD Signal (arb)')
    plt.show()

# %%
finalPD = [PDvalue5,PDvalue6,PDvalue7,PDvalue8,PDvalue9];

# %%
print (finalPD)
# Out:
# [[0.1691, 0.1688, 0.1702, 0.171, 0.1702, 0.171, 0.1699, 0.167, 0.1694, 0.1702, 0.1708, 0.1687, 0.1691, 0.1696, 0.1697, 0.1682, 0.1685, 0.1706, 0.1706, 0.1706, 0.1723, 0.1723, 0.1723, 0.1741, 0.1738, 0.1732, 0.1756, 0.1723, 0.1729, 0.1723, 0.1718, 0.1723, 0.1716, 0.1712, 0.1741, 0.1744, 0.1723, 0.1758, 0.1741, 0.1708, 0.1729, 0.1688, 0.1694, 0.1716, 0.1741, 0.169, 0.1685, 0.1703, 0.1716, 0.1696, 0.171, 0.1721, 0.171, 0.1694, 0.1702, 0.1715, 0.1732, 0.1764, 0.1744, 0.1714, 0.17, 0.1712, 0.1712, 0.1714, 0.17, 0.171, 0.1729, 0.1719, 0.1705, 0.1706, 0.17, 0.1674, 0.1685, 0.1713, 0.1685, 0.1712, 0.1716, 0.17, 0.1697, 0.1708, 0.1694, 0.1696, 0.1699, 0.171, 0.1704, 0.1706, 0.1704, 0.1735, 0.1729, 0.1735, 0.172, 0.1661, 0.1666, 0.167, 0.1682, 0.1668, 0.1679, 0.1664, 0.1664, 0.1654, 0.167, 0.166, 0.1662, 0.1622, 0.1658, 0.1664, 0.1676, 0.1673, 0.1666, 0.1682, 0.1692, 0.1679, 0.1673, 0.1676, 0.1676, 0.167, 0.1658, 0.1673, 0.1679, 0.1682, 0.17, 0.1685, 0.1691, 0.1694, 0.1691, 0.1697, 0.1705, 0.1
# ...

# %%
FinalaveragePD = [];
X = [];
averagePD = [];

for i in range(len(finalPD[0])):
    #print ([finalPD[0][i], finalPD[1][i], finalPD[2][i], finalPD[3][i], finalPD[4][i]])
    #print(np.mean([finalPD[0][i], finalPD[1][i], finalPD[2][i], finalPD[3][i], finalPD[4][i]]))
    averagePD = np.sum([finalPD[0][i],finalPD[1][i],finalPD[2][i],finalPD[3][i],finalPD[4][i]])/len(finalPD)
    FinalaveragePD.append(averagePD)
#print(FinalaveragePD)
plt.plot(times, PDvalue, 'r',times,FinalaveragePD,'b')
plt.xlabel('Stage Position (arb)')
plt.ylabel('PD Signal (arb)')
plt.show()

# %%
len(PDvalue5)
# Out:
# 768

# %%
len(FinalaveragePD)
# Out:
# 767

# %%
finalPD[0][0]
# Out:
# 0.1691

# %%
finalPD[1][0]
# Out:
# 0.1682

# %%
finalPD[2][0]
# Out:
# 0.17

# %%
finalPD[3][0]
# Out:
# 0.1697

# %%
finalPD[4][0]
# Out:
# 0.1672

# %%
# Out:
# [0.1672,
#  0.166,
#  0.166,
#  0.1666,
#  0.165,
#  0.1644,
#  0.166,
#  0.165,
#  0.1647,
#  0.1662,
#  0.1656,
#  0.1656,
#  0.166,
#  0.1666,
#  0.1656,
#  0.1664,
#  0.1664,
#  0.1656,
#  0.1629,
#  0.1623,
#  0.1647,
#  0.167,
#  0.165,
#  0.1624,
#  0.1628,
#  0.1673,
#  0.1668,
#  0.1656,
#  0.1623,
#  0.1629,
#  0.1635,
#  0.1671,
#  0.1685,
#  0.1666,
#  0.167,
#  0.1668,
#  0.1682,
#  0.1691,
#  0.1696,
#  0.1696,
#  0.1673,
#  0.1673,
#  0.1664,
#  0.1656,
#  0.1647,
#  0.165,
#  0.1664,
#  0.167,
#  0.1645,
#  0.1616,
#  0.1608,
#  0.1623,
#  0.1625,
#  0.161,
#  0.1623,
#  0.1604,
#  0.162,
#  0.1608,
#  0.1616,
#  0.1626,
#  0.1629,
#  0.1626,
#  0.1631,
#  0.1598,
#  0.1576,
#  0.1582,
#  0.1594,
#  0.1576,
#  0.157,
#  0.1573,
#  0.161,
#  0.1602,
#  0.1655,
#  0.1651,
#  0.167,
#  0.1676,
#  0.1656,
#  0.1658,
#  0.166,
#  0.1666,
#  0.167,
#  0.1682,
#  0.1671,
#  0.1671,
#  0.1641,
#  0.1641,
#  0.1604,
#  0.1613,
#  0.1658,
#  0.1664,
#  0.1668,
#  0.1666,
# ...

# %%
avg = np.mean([finalPD[0][0], finalPD[1][0],finalPD[2][0], finalPD[3][0],finalPD[4][0]])
avg2= np.mean([finalPD[0][1], finalPD[1][1],finalPD[2][1], finalPD[3][1],finalPD[4][1]])
favg = [];

# %%
favg.append([avg, avg2])

# %%
favg
# Out:
# [[0.16883999999999999, 0.16848000000000002]]

# %%
# Out:
# 767

# %%
FinalaveragePD[0]
# Out:
# 0.16883999999999999
